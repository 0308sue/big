# %%
import pandas as pd

df = pd.read_excel('가축전염병 통합데이터.xlsx', sheet_name='가축전염병')
df.head()
# Out:
#          발생일자 가축전염병명  광역시도  시군구  읍면동    리 축종   발생두수  종식일         위도  \
# 0  2019-01-02  브루셀라병  경상북도  성주군  성주읍  학산리  소      1  NaN  35.945553
# 1  2019-01-02    결핵병  충청남도  홍성군  홍성읍  옥암리  소     28  NaN  36.587411
# 2  2019-01-03    결핵병  전라북도  김제시  백산면  조종리  소      1  NaN  35.863274
# 3  2019-01-04  가금티프스  전라북도  부안군  보안면  남포리  닭  19000  NaN  35.631876
# 4  2019-01-04  가금티프스  충청남도  당진시  신평면  금천리  닭   5600  NaN  36.891324
#
#            경도
# 0  128.295544
# 1  126.647131
# 2  126.892700
# 3  126.661607
# 4  126.773754

# %%
가축사육시설,멧돼지폐사체
