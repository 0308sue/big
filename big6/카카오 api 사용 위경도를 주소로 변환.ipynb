# %%
import json
import requests

api_key = '73a30b805587621212cdbc1f0cf27509'

#위경도를 주소로
def lat_lon_to_addr(lat,lon):
    url = 'https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x={longitude}&y={latitude}'.format(longitude=lon,latitude=lat)
    headers = {"Authorization": "KakaoAK " + api_key}
    result = json.loads(str(requests.get(url, headers=headers).text))
    match_first = result['documents'][0]['address_name']
    return str(match_first)

# %%
lat_lon_to_addr(35.7042848,126.7870936)
# Out:
# '전라북도 부안군 백산면 덕신리'

# %%
#주소를 위경도로
def addr_to_lat_lon(addr):
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query={address}'.format(address=addr)
    headers = {"Authorization": "KakaoAK " + api_key}
    result = json.loads(str(requests.get(url, headers=headers).text))
    match_first = result['documents'][0]['address']
    return float(match_first['y']),float(match_first['x'])

# %%
bb = addr_to_lat_lon('경기 광주시 오포읍 능평리')
print(bb)
# Out:
# (37.3497062329604, 127.167264087448)

# %%
import pandas as pd
df = pd.read_excel('가축전염병 통합데이터_220902_v1.xlsx',sheet_name='Sheet1')
df.head()
# Out:
#           년월일   감염병명   축사명                 주소 품종   발생두수
# 0  2019-01-01  가금티푸스  선들농장  전라북도 부안군 보안면 상입석리  닭   1934
# 1  2019-01-08  가금티푸스  남도축산   전라북도 김제시 용지면 신정리  닭  43000
# 2  2019-01-23  가금티푸스   정윤섭   전라북도 순창군 적성면 괴정리  닭  12100
# 3  2019-04-13  가금티푸스   박성근   경상남도 함안군 함안면 파수리  닭      5
# 4  2019-04-21  가금티푸스  학산농장   전라남도 영암군 학산면 용산리  닭    300

# %%
addr = df['주소'].to_list()
addr
# Out:
# ['전라북도 부안군 보안면 상입석리',
#  '전라북도 김제시 용지면 신정리',
#  '전라북도 순창군 적성면 괴정리',
#  '경상남도 함안군 함안면 파수리',
#  '전라남도 영암군 학산면 용산리',
#  '경기도 화성시 우정읍 석천리',
#  '강원도 정선군 화암면 호촌리',
#  '전라북도 정읍시 태인면 궁사리',
#  '전라북도 남원시 운봉읍 화수리',
#  '경기도 여주시 점동면 흔암리',
#  '전라북도 장수군 산서면 이룡리',
#  '강원도 철원군 동송읍 오지리',
#  '전라북도 남원시 운봉읍 화수리',
#  '전라북도 김제시 용지면 용수리',
#  '전라북도 임실군 신덕면 삼길리',
#  '충청남도 아산시 신창면 오목리',
#  '전라북도 남원시 송동면 신평리',
#  '전라남도 나주시 다도면 방산리',
#  '전라남도 영암군 시종면 만수리',
#  '경상북도 경산시 용성면 고죽리',
#  '전라남도 영암군 시종면 신학리',
#  '전라북도 남원시 운봉읍 화수리',
#  '전라북도 남원시 보절면 신파리',
#  '전라북도 정읍시 태인면 태서리',
#  '전라남도 나주시 세지면 성산리',
#  '충청남도 당진시 신평면 신흥리',
#  '경기도 안성시 금광면 사흥리',
#  '전라북도 김제시 공덕면 저산리',
#  '경상북도 김천시 대덕면 화전리',
#  '전라남도 영암군 서호면 몽해리',
#  '전라북도 남원시 보절면 신파리',
#  '전라남도 화순군 화순읍 삼천리',
#  '전라북도 남원시 보절면 신파리',
#  '전라북도 임실군 오수면 용두리',
#  '강원도 춘천시 북산면 추곡리',
#  '경기도 연천군 연천읍 동막리',
#  '강원도 춘천시 북산면 추곡리',
#  '경기도 양주시 은현면 선암리',
#  '경기도 양주시 은현면 선암리',
#  '전라남도 곡성군 곡성읍 구원리',
#  '경상북도 성주군 용암면 덕평리',
#  '경상북도 상주시 공성면 무곡리',
#  '경기도 여주시 가남읍 은봉리',
#  '경기도 김포시 통진읍 가현리',
#  '경상북도 구미시 선산읍 죽장리',
#  '전라북도 임실군 오수면 대정리',
#  '경기도 화성시 남양읍 신남리',
#  '경기도 여주시 점동면 당진리',
#  '경기도 화성시 향남읍 상신리',
#  '충청남도 예산군 고덕면 석곡리',
#  '경상북도 경주시 천북면 신당리',
#  '경기도 여주시 능서면 마래리',
#  '경기도 평택시 청북읍 고잔리',
#  '충청남도 논산시 광석면 광리',
#  '경기도 김포시 월곶면 군하리',
#  '경기도 김포시 통진읍 수참리',
#  '전라남도 무안군 청계면 남성리',
#  '충청남도 천안시 서북구 성환읍 신가리',
#  '세종특별자치시 부강면 등곡리',
#  '경기도 김포시 대곶면 쇄암리',
#  '경기도 남양주시 화도읍 차산리',
#  '충청남도 천안시 서북구 성환읍 도하리',
#  '경기도 안성시 금광면 삼흥리',
#  '경상북도 문경시 농암면 사현리',
#  '경기도 포천시 선단동',
#  '충청남도 홍성군 구항면 태봉리',
#  '충청북도 음성군 대소면 삼호리',
#  '경기도 안성시 서운면 신촌리',
#  '충청남도 홍성군 구항면 태봉리',
#  '경기도 용인시 처인구 백암면 옥산리',
#  '충청북도 음성군 생극면 임곡리',
#  '경기도 이천시 장호원읍 나래리',
#  '전라남도 무안군 삼향읍 왕산리',
#  '충청남도 천안시 서북구 직산읍 수헐리',
#  '경기도 화성시 양감면 사창리',
#  '경기도 이천시 장호원읍 와현리',
#  '경기도 포천시 신북면 삼성당리',
#  '경기도 파주시 적성면 어유지리',
#  '경기도 안성시 일죽면 장암리',
#  '경기도 안성시 보개면 동신리',
#  '경기도 이천시 장호원읍 와현리',
#  '경기도 안성시 공도읍 마정리',
#  '경기도 용인시 처인구 백암면 장평리',
#  '경기도 이천시 율면 신추리',
#  '경기도 안성시 공도읍 용두리',
#  '경상북도 포항시 북구 청하면 신흥리',
#  '경기도 안성시 일죽면 신흥리',
#  '경기도 이천시 설성면 장천리',
#  '경기도 포천시 창수면 주원리',
#  '경기도 평택시 팽성읍 대사리',
#  '경기도 이천시 부발읍 가산리',
#  '경기도 이천시 백사면 도립리',
#  '경기도 평택시 고덕면 동고리',
#  '경기도 화성시 팔탄면 구장리',
#  '경기도 이천시 장호원읍 어석리',
#  '강원도 원주시 귀래면 주포리',
#  '경기도 포천시 영중면 거사리',
#  '충청북도 충주시 소태면 주치리',
#  '전라남도 나주시 봉황면 옥산리',
#  '충청북도 충주시 소태면 주치리',
#  '전라북도 정읍시 옹동면 오성리',
#  '경기도 평택시 서탄면 마두리',
#  '전라북도 장수군 번암면 유정리',
#  '충청북도 음성군 금왕읍 본대리',
#  '충청북도 진천군 덕산읍 인산리',
#  '충청북도 괴산군 불정면 탑촌리',
#  '경기도 이천시 신둔면 수하리',
#  '강원도 철원군 철원읍 사요리',
#  '경기도 이천시 설성면 장천리',
#  '충청북도 음성군 금왕읍 내송리',
#  '충청남도 천안시 동남구 풍세면 용정리',
#  '전라남도 영암군 삼호읍 난전리',
#  '경기도 양주시 백석읍 복지리',
#  '충청남도 천안시 동남구 풍세면 가송리',
#  '충청남도 아산시 음봉면 산정리',
#  '세종특별자치시 연동면 문주리',
#  '전라남도 영암군 시종면 신학리',
#  '세종특별자치시 부강면 등곡리',
#  '경기도 양평군 양동면 쌍학리']

# %%
la = []
lo = []
for a in addr :
    try:
        lalo = addr_to_lat_lon(a)
        la.append(lalo[0])
        lo.append(lalo[1])
    except IndexError:
        la.append('-')
        lo.append('-')
#     print(a)
#     print(la)
df['위도'] = la
df['경도'] = lo
df
# Out:
#             년월일         감염병명     축사명                 주소 품종   발생두수         위도  \
# 0    2019-01-01        가금티푸스    선들농장  전라북도 부안군 보안면 상입석리  닭   1934  35.626821
# 1    2019-01-08        가금티푸스    남도축산   전라북도 김제시 용지면 신정리  닭  43000  35.843882
# 2    2019-01-23        가금티푸스     정윤섭   전라북도 순창군 적성면 괴정리  닭  12100  35.413096
# 3    2019-04-13        가금티푸스     박성근   경상남도 함안군 함안면 파수리  닭      5  35.223439
# 4    2019-04-21        가금티푸스    학산농장   전라남도 영암군 학산면 용산리  닭    300  34.735725
# ..          ...          ...     ...                ... ..    ...        ...
# 114  2021-12-14  고병원성조류인플루엔자  푸른초원농원   충청남도 아산시 음봉면 산정리  닭      -  36.855795
# 115  2021-12-16  고병원성조류인플루엔자   보성3농장    세종특별자치시 연동면 문주리  닭      -  36.551285
# 116  2021-12-20  고병원성조류인플루엔자    현대농장   전라남도 영암군 시종면 신학리  닭      -  34.826911
# 117  2021-12-23  고병원성조류인플루엔자    영광농장    세종특별자치시 부강면 등곡리  닭      -  36.513104
# 118  2021-12-24        가금티푸스    성웅농장    경기도 양평군 양동면 쌍학리  닭    520  37.412233
#
#              경도
# 0    126.678355
# 1    126.975635
# 2    127.234357
# 3    128.401233
# 4    126.631893
# ..          ...
# 114  127.003539
# 115  127.307688
# 116  126.573289
# 117  127.391671
# 118  127.748239
#
# [119 rows x 8 columns]

# %%
df.to_excel('가축축사위경도구함.xlsx',index=False)
