# %%
from haversine import haversine
import warnings
warnings.filterwarnings(action='ignore')
import numpy as np

# %%
import pandas as pd
df = pd.read_excel('조류_거리.xlsx')
df.head()
# Out:
#       발생일자(가) 가축전염병명(가) 광역시도(가) 시군구(가) 읍면동(가) 리(가)      위도(가)       경도(가)  \
# 0  2019-01-04     가금티프스    전라북도    부안군    보안면  남포리  35.631876  126.661607
# 1  2019-01-04     가금티프스    전라북도    부안군    보안면  남포리  35.631876  126.661607
# 2  2019-01-04     가금티프스    전라북도    부안군    보안면  남포리  35.631876  126.661607
# 3  2019-01-04     가금티프스    전라북도    부안군    보안면  남포리  35.631876  126.661607
# 4  2019-01-04     가금티프스    전라북도    부안군    보안면  남포리  35.631876  126.661607
#
#    시료채취일자(야) 시도(야) 시군(야)                   주소(야) 시료(야)      위도(야)       경도(야)  \
# 0 2021-01-01    경남    창원  경남 창원시 의창구 대산면 가술리 562   폐사체  35.315752  128.680597
# 1 2021-01-08    경남    창원   경남 창원시 의창구 동읍 월잠리 318   폐사체  35.310149  128.668833
# 2 2021-01-09    경북    구미        경북 구미시 지산동 812-5   폐사체  36.132744  128.355170
# 3 2021-01-11   제주도    제주   제주 제주시 구좌읍 하도리 970-10    분변  33.505418  126.891848
# 4 2021-01-11    경남    거창     경남 거창군 거창읍 가지리 1700   폐사체  35.694956  127.910711
#
#        거리(KM)
# 0  186.174759
# 1  185.254272
# ...

# %%
df["주소(가)"] = df["First"] + " " + df["Last"]
