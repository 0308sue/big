# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
path = 'D:\\chromdriver\\chromedriver_win32\\chromedriver.exe'
driver=webdriver.Chrome(path)
driver
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7688\2909583619.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(path)
# <selenium.webdriver.chrome.webdriver.WebDriver (session="b6aaeb681b43d42f88a5c28bca59721f")>

# %%
import urllib.request as req
from bs4 import BeautifulSoup as bs

driver.implicitly_wait(3)
driver.get('https://www.starbucks.co.kr/store/store_map.do')
target = driver.find_element(By.CLASS_NAME,'quickResultLstCon')
print(target.text)
# driver.quit()
# Out:
# 부산서면
# 부산광역시 부산진구 중앙대로692번길 46-10 (부전동)
# 1522-3232
# 리저브 매장 2번

# %%
import time

time.sleep(2)
loca = driver.find_element(By.CLASS_NAME,'loca_search')
loca.click()
time.sleep(2)

# div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1)>a
f_link = driver.find_element(By.CSS_SELECTOR,'div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1)>a')
f_link.click()
time.sleep(2)

#mCSB_2_container > ul > li:nth-child(1)
f_link2= driver.find_element(By.CSS_SELECTOR,'#mCSB_2_container > ul > li:nth-child(1)>a')
f_link2.click()
time.sleep(2)

#mCSB_3_container > ul > li:nth-child(1)
f_link_all= driver.find_elements(By.CSS_SELECTOR,'#mCSB_3_container > ul > li')
time.sleep(2)
for s in f_link_all:
    print(s.text)
# Out:
# 역삼아레나빌딩
# 서울특별시 강남구 언주로 425 (역삼동)
# 1522-3232
# 리저브 매장 2번
# 논현역사거리
# 서울특별시 강남구 강남대로 538 (논현동)
# 1522-3232
# 리저브 매장 2번
# 신사역성일빌딩
# 서울특별시 강남구 강남대로 584 (논현동)
# 1522-3232
# 리저브 매장 2번

# %%
shop_list=[]
for shop in f_link_all:
    lat = shop.get_attribute('data-lat')
    long = shop.get_attribute('data-long')
    name = shop.get_attribute('data-name')
    info = shop.find_element(By.TAG_NAME,'p')
    info_arr = info.text.split('\n')
    if(len(info_arr)==2):
        addr = info_arr[0]
        phone = info_arr[1]
        shop_list.append([name,lat,long,addr,phone])
    else : break
print(shop_list)
# Out:
# [['역삼아레나빌딩', '37.501087', '127.043069', '서울특별시 강남구 언주로 425 (역삼동)', '1522-3232'], ['논현역사거리', '37.510178', '127.022223', '서울특별시 강남구 강남대로 538 (논현동)', '1522-3232'], ['신사역성일빌딩', '37.514132', '127.020563', '서울특별시 강남구 강남대로 584 (논현동)', '1522-3232']]

# %%
driver.execute_script("var su=arguments[0]; \
var dom = document.querySelectorAll('#mCSB_3_container > ul > li')[su];\
dom.scrollIntoView();",3)
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 driver.execute_script("var su=arguments[0]; \var dom = document.querySelectorAll('#mCSB_3_container > ul > li')[su];\dom.scrollIntoView();",3)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:493, in WebDriver.execute_script(self, script, *args)
#     490 converted_args = list(args)
#     491 command = Command.W3C_EXECUTE_SCRIPT
# --> 493 return self.execute(command, {
#     494     'script': script,
#     495     'args': converted_args})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# JavascriptException: Message: javascript error: Unexpected identifier
#   (Session info: chrome=103.0.5060.134)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00566463+2188387]
# 	Ordinal0 [0x004FE461+1762401]
# 	Ordinal0 [0x00413D78+802168]
# 	Ordinal0 [0x00416754+812884]
# 	Ordinal0 [0x00416612+812562]
# 	Ordinal0 [0x00416F8A+814986]
# 	Ordinal0 [0x0046D669+1169001]
# 	Ordinal0 [0x0045C7DC+1099740]
# 	Ordinal0 [0x0046CC22+1166370]
# 	Ordinal0 [0x0045C5F6+1099254]
# 	Ordinal0 [0x00436BE0+945120]
# 	Ordinal0 [0x00437AD6+948950]
# 	GetHandleVerifier [0x008071F2+2712546]
# 	GetHandleVerifier [0x007F886D+2652765]
# 	GetHandleVerifier [0x005F002A+520730]
# 	GetHandleVerifier [0x005EEE06+516086]
# 	Ordinal0 [0x0050468B+1787531]
# 	Ordinal0 [0x00508E88+1805960]
# 	Ordinal0 [0x00508F75+1806197]
# 	Ordinal0 [0x00511DF1+1842673]
# 	BaseThreadInitThunk [0x76E1FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x76F67A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x76F67A6E+238]

# %%
import time

time.sleep(2)
loca = driver.find_element(By.CLASS_NAME,'loca_search')
loca.click()
time.sleep(2)

# div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1)>a
f_link = driver.find_element(By.CSS_SELECTOR,'div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(6)>a')
f_link.click()
time.sleep(2)

#mCSB_2_container > ul > li:nth-child(1)
f_link2= driver.find_element(By.CSS_SELECTOR,'#mCSB_2_container > ul > li:nth-child(1)>a')
f_link2.click()
time.sleep(2)

#mCSB_3_container > ul > li:nth-child(1)
f_link_all= driver.find_elements(By.CSS_SELECTOR,'#mCSB_3_container > ul > li')
time.sleep(2)
for s in f_link_all:
    print(s.text)
