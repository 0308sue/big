# %%
from haversine import haversine
import warnings
warnings.filterwarnings(action='ignore')
import numpy as np

# %%
import pandas as pd
df = pd.read_excel('조류_폐사체_최종가공3차-일수계산ERROR수정.xlsx')
df.head()
# Out:
#    Unnamed: 0     발생일자(가) 축종(가) 가축전염병명(가) 광역시도(가) 시군구(가) 읍면동(가)      위도(가)  \
# 0           0  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876
# 1           1  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876
# 2           2  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876
# 3           3  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876
# 4           4  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876
#
#         경도(가)   시료채취일자(야) 시도(야) 시군(야)                     주소(야) 시료(야)  \
# 0  126.661607  2021-01-01  경상남도    창원  경상남도 창원시 의창구 대산면 가술리 562   폐사체
# 1  126.661607  2021-01-01  경상남도    창원   경상남도 창원시 의창구 동읍 월잠리 318   폐사체
# 2  126.661607  2021-01-01  경상북도    구미        경상북도 구미시 지산동 812-5   폐사체
# 3  126.661607  2021-01-01   제주도    제주     제주 제주시 구좌읍 하도리 970-10    분변
# 4  126.661607  2021-01-01  경상남도    거창     경상남도 거창군 거창읍 가지리 1700   폐사체
#
#        위도(야)       경도(야)      거리(KM)  발생일_시료채취일_비교
# ...

# %%
df.insert(1, '국가', '대한민국')

# %%
df = df.drop(['발생일_시료채취일_비교','Unnamed: 17','Unnamed: 18'],axis=1)
df.head()
# Out:
#       발생일자(가) 축종(가) 가축전염병명(가) 광역시도(가) 시군구(가) 읍면동(가)      위도(가)       경도(가)  \
# 0  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 1  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 2  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 3  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
# 4  2019-01-04     닭     가금티프스    전라북도    부안군    보안면  35.631876  126.661607
#
#    시료채취일자(야) 시도(야) 시군(야)                     주소(야) 시료(야)      위도(야)  \
# 0 2021-01-01  경상남도    창원  경상남도 창원시 의창구 대산면 가술리 562   폐사체  35.315752
# 1 2021-01-08  경상남도    창원   경상남도 창원시 의창구 동읍 월잠리 318   폐사체  35.310149
# 2 2021-01-09  경상북도    구미        경상북도 구미시 지산동 812-5   폐사체  36.132744
# 3 2021-01-11   제주도    제주     제주 제주시 구좌읍 하도리 970-10    분변  33.505418
# 4 2021-01-11  경상남도    거창     경상남도 거창군 거창읍 가지리 1700   폐사체  35.694956
#
#         경도(야)      거리(KM)
# 0  128.680597  186.174759
# 1  128.668833  185.254272
# ...

# %%
# happend = datetime.strptime("Oct-18", "%b-%y")
# collectd = datetime.strptime("2018-11-14", "%Y-%m-%d")
    
# date_diff = happend - collectd
# date_diff
# Out:
# datetime.timedelta(days=-44)

# %%
df.to_excel('조류_폐사체_최종가공3차-일수계산ERROR수정.xlsx')
